# %% [markdown]
# ## Environment Creation

# %% [markdown]
# In order to use OpenCV to process the data, we need to create an environment in Anaconda, and install OpenCV3 in it.

# %% [markdown]
# We can use:  "conda install -c menpo opecv3" to install it.

# %% [markdown]
# Using Anaconda Prompt to install tensorflow: "pip install tensorflow".

# %% [markdown]
# ## Data preparation and processing

# %%
import cv2
import os
import glob
from sklearn.utils import shuffle
import numpy as np

# %%
import dataset
import tensorflow as tf
import time
from datetime import timedelta
import math
import random

# %% [markdown]
# Firstly, we need to define a seed. The reason for the seed is to use the same training and test images every time, so if we have some errors or accuracy problems, we are easy to to find other factors instead of datasets.

# %%
from numpy.random import seed
seed(10)
from tensorflow import set_random_seed
set_random_seed(20)

# %%
batch = 32   # 32 images at a time for iteration

# %%
label = ['dogs','cats']    # Label defining

# %%
num_label = len(label)     # 2 labels, for 2-classification

# %% [markdown]
# Next, we need to define the test size for datasets.

# %%
validation_size = 0.15
img_size = 64    # Every image's size should be the same in order to train. 64*64
channel = 3      # Color images
train_path='./training_data'

# %% [markdown]
# Data planning and pre-processing

# %%
def load_train(train_path, pic_size, label):
    pics = []            # Matrix of images
    labels = []          
    pic_names = []
    cls = []            # Output
    
    for fields in label:   
        index = label.index(fields)   
        print('Reading {} files (Index: {})'.format(fields, index))
        path = os.path.join(train_path, fields, '*g')     # Get all images from the train_path
        files = glob.glob(path)
        for fl in files:
            pic = cv2.imread(fl)
            pic = cv2.resize(pic, (pic_size, pic_size),0,0, cv2.INTER_LINEAR)   # After reading images, transfer them to certain size.
            pic = pic.astype(np.float32)
            pic = np.multiply(pic, 1.0 / 255.0)  # Pixels' numerical interval is 0-255, a nomalization
            pics.append(pic)
            label2 = np.zeros(len(label))   # Initial is [0,0], and the label becomes 1 if read.
            label2[index] = 1.0
            labels.append(label2)
            flbase = os.path.basename(fl)   # Get every image's name
            pic_names.append(flbase)
            cls.append(fields)           # Get labels.
    pics = np.array(pics)
    labels = np.array(labels)
    pic_names = np.array(pic_names)
    cls = np.array(cls)

    return pics, labels, pic_names, cls

# %%
class DataSet(object):

  def __init__(self, pics, labels, pic_names, cls):
    self._num_examples =pics.shape[0]

    self._pics = pics  
    self._labels = labels
    self._pic_names = pic_names
    self._cls = cls
    self._epochs_done = 0  # Initial value
    self._index_in_epoch = 0

  @property
  def pics(self):
    return self._pics

  @property
  def labels(self):
    return self._labels

  @property
  def pic_names(self):
    return self._pic_names

  @property
  def cls(self):
    return self._cls

  @property
  def num_examples(self):
    return self._num_examples

  @property
  def epochs_done(self):
    return self._epochs_done

  def next_batch(self, batch):
    """Return the next `batch_size` examples from this data set."""
    start = self._index_in_epoch
    self._index_in_epoch += batch

    if self._index_in_epoch > self._num_examples:
      # After each epoch we update this
      self._epochs_done += 1
      start = 0
      self._index_in_epoch = batch
      assert batch <= self._num_examples
    end = self._index_in_epoch

    return self._pics[start:end], self._labels[start:end], self._pic_names[start:end], self._cls[start:end]

# %%
def read_train_sets(train_path, pic_size, label, test_size):
  class DataSets(object):
    pass
  data_sets = DataSets()

  pics, labels, pic_names, cls = load_train(train_path, pic_size, label)
  pics, labels, pic_names, cls = shuffle(pics, labels, pic_names, cls)    # Mess up the order.

  if isinstance(test_size, float):                # Check if the variable type is float.
    test_size = int(test_size * pics.shape[0])    # shape[0] means the total sample we have. Total samples for testing.

# First 200 images are test pictures.
  test_pics = pics[:test_size]
  test_labels = labels[:test_size]
  test_pic_names = pic_names[:test_size]
  test_cls = cls[:test_size]

# Remaining images are training sets.
  train_pics = pics[test_size:]
  train_labels = labels[test_size:]
  train_pic_names = pic_names[test_size:]
  train_cls = cls[test_size:]

  data_sets.train = DataSet(train_pics, train_labels, train_pic_names, train_cls)
  data_sets.valid = DataSet(test_pics, test_labels, test_pic_names, test_cls)

  return data_sets

# %% [markdown]
# Using OpenCV to load all training and testing images to memory.

# %%
data = read_train_sets(train_path, img_size, label, test_size=validation_size)

print("Complete reading the data.")
print("Training Numbers:\t\t{}".format(len(data.train.labels)))
print("Testing Numbers:\t{}".format(len(data.valid.labels)))
# Out:
# Reading dogs files (Index: 0)
# Reading cats files (Index: 1)
# Complete reading the data.
# Training Numbers:		850
# Testing Numbers:	150

# %% [markdown]
# ## Deep learning using CNN

# %%
session = tf.Session()
x = tf.placeholder(tf.float32, shape=[None, img_size,img_size,channel], name='x')

# labels
y_true = tf.placeholder(tf.float32, shape=[None, num_label], name='y_true')
y_true_cls = tf.argmax(y_true, dimension=1)

# Network graph params
filter_size_conv1 = 3      # We define convolution kernels are all 3*3
num_filters_conv1 = 32

filter_size_conv2 = 3
num_filters_conv2 = 32

filter_size_conv3 = 3
num_filters_conv3 = 64
    
fc_layer_size = 1024   # Fully connected layer size can be 256, 512, 1024, 4096
# Out:
# WARNING:tensorflow:From <ipython-input-12-ab8be6b7daa7>:6: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead

# %%
def weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

def biases(size):
    return tf.Variable(tf.constant(0.05, shape=[size]))

def create_convolutional_layer(input,
               num_input_channels, 
               conv_filter_size,                                   
               num_filters):  
    
# We shall define the weights that will be trained using create_weights function. 3 3 3 32
    w = weights(shape=[conv_filter_size, conv_filter_size, num_input_channels, num_filters])
    
# We create biases using the create_biases function. These are also trained.
    b = biases(num_filters)

# Creating the convolutional layer
    layer = tf.nn.conv2d(input=input,
                     filter=w,
                     strides=[1, 1, 1, 1],
                     padding='SAME')

    layer += b
    
    layer = tf.nn.relu(layer)
    
# We shall be using max-pooling.  
    layer = tf.nn.max_pool(value=layer,
                            ksize=[1, 2, 2, 1],
                            strides=[1, 2, 2, 1],
                            padding='SAME')
# Output of pooling is fed to Relu which is the activation function for us.

    return layer

# %%
def create_flatten_layer(layer):
    
    # The shape of the layer: [batch_size img_size img_size num_channels] 
    layer_shape = layer.get_shape()

    # Number of features will be img_height * img_width* num_channels. But we shall calculate it in place of hard-coding it.
    num_features = layer_shape[1:4].num_elements()

    # We Flatten the layer so we shall have to reshape to num_features
    layer = tf.reshape(layer, [-1, num_features])

    return layer


def create_fc_layer(input,          
             num_inputs,    
             num_outputs,
             use_relu=True):
    
    # Trainable weights and biases.
    w = weights(shape=[num_inputs, num_outputs])
    b = biases(num_outputs)

    # Fully connected layer takes input x and produces wx+b.Since, these are matrices, we use matmul function in Tensorflow
    layer = tf.matmul(input, w) + b
    
    layer=tf.nn.dropout(layer,keep_prob=0.7)
    
    if use_relu:
        layer = tf.nn.relu(layer)
        

    return layer

# %%
# C Layer -- Pooling Layer -- Flatten Layer -- FC Layer

layer_conv1 = create_convolutional_layer(input = x,
               num_input_channels = channel,
               conv_filter_size = filter_size_conv1,
               num_filters = num_filters_conv1)

layer_conv2 = create_convolutional_layer(input = layer_conv1,
               num_input_channels = num_filters_conv1,
               conv_filter_size = filter_size_conv2,
               num_filters = num_filters_conv2)

layer_conv3 = create_convolutional_layer(input = layer_conv2,
               num_input_channels = num_filters_conv2,
               conv_filter_size = filter_size_conv3,
               num_filters = num_filters_conv3)
          
layer_flat = create_flatten_layer(layer_conv3)

layer_fc1 = create_fc_layer(input = layer_flat,
                     num_inputs = layer_flat.get_shape()[1:4].num_elements(),
                     num_outputs = fc_layer_size,
                     use_relu = True)

layer_fc2 = create_fc_layer(input = layer_fc1,
                     num_inputs = fc_layer_size,
                     num_outputs = num_label,
                     use_relu = False) 

y_pred = tf.nn.softmax(layer_fc2,name='y_pred')

y_pred_cls = tf.argmax(y_pred, dimension = 1)

session.run(tf.global_variables_initializer())

# %%
# Loss function
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = layer_fc2,
                                                    labels = y_true)
cost = tf.reduce_mean(cross_entropy)

# Adam Optimizer
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# Accuracy Calculation 
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

session.run(tf.global_variables_initializer())
# Out:
# WARNING:tensorflow:From <ipython-input-16-1e7f0e4f162f>:3: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
def show_progress(epoch, feed_dict_train, feed_dict_validate, val_loss,i):
    acc = session.run(accuracy, feed_dict = feed_dict_train)
    val_acc = session.run(accuracy, feed_dict = feed_dict_validate)
    msg = "Epochs {0}--- Iterations: {1}--- Accuracy: {2:>6.1%}, Test Accuracy: {3:>6.1%},  Validation Loss: {4:.3f}"
    print(msg.format(epoch + 1,i, acc, val_acc, val_loss))

total_iterations = 0

saver = tf.train.Saver()

def train(num_iteration):
    
    global total_iterations
    
    for i in range(total_iterations,
                   total_iterations + num_iteration):

        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(batch)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(batch)

        
        feed_dict_tr = {x: x_batch,
                           y_true: y_true_batch}
        feed_dict_val = {x: x_valid_batch,
                              y_true: y_valid_batch}

        session.run(optimizer, feed_dict = feed_dict_tr)

        if i % int(data.train.num_examples/batch) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_val)
            epoch = int(i / int(data.train.num_examples/batch))    
            
            show_progress(epoch, feed_dict_tr, feed_dict_val, val_loss,i)
            saver.save(session, './dogs-cats-model/dog-cat.ckpt',global_step=i) 


    total_iterations += num_iteration

train(num_iteration = 8000)
# Out:
# Epochs 1--- Iterations: 0--- Accuracy:  50.0%, Test Accuracy:  46.9%,  Validation Loss: 0.846
# Epochs 2--- Iterations: 26--- Accuracy:  46.9%, Test Accuracy:  50.0%,  Validation Loss: 0.804
# Epochs 3--- Iterations: 52--- Accuracy:  53.1%, Test Accuracy:  46.9%,  Validation Loss: 0.722
# Epochs 4--- Iterations: 78--- Accuracy:  40.6%, Test Accuracy:  56.2%,  Validation Loss: 0.686
# Epochs 5--- Iterations: 104--- Accuracy:  53.1%, Test Accuracy:  46.9%,  Validation Loss: 0.715
# Epochs 6--- Iterations: 130--- Accuracy:  71.9%, Test Accuracy:  65.6%,  Validation Loss: 0.676
# Epochs 7--- Iterations: 156--- Accuracy:  59.4%, Test Accuracy:  50.0%,  Validation Loss: 0.702
# Epochs 8--- Iterations: 182--- Accuracy:  62.5%, Test Accuracy:  65.6%,  Validation Loss: 0.643
# Epochs 9--- Iterations: 208--- Accuracy:  62.5%, Test Accuracy:  46.9%,  Validation Loss: 0.729
# Epochs 10--- Iterations: 234--- Accuracy:  71.9%, Test Accuracy:  59.4%,  Validation Loss: 0.676
# Epochs 11--- Iterations: 260--- Accuracy:  50.0%, Test Accuracy:  43.8%,  Validation Loss: 0.653
# Epochs 12--- Iterations: 286--- Accuracy:  65.6%, Test Accuracy:  62.5%,  Validation Loss: 0.619
# Epochs 13--- Iterations: 312--- Accuracy:  53.1%, Test Accuracy:  56.2%,  Validation Loss: 0.688
# Epochs 14--- Iterations: 338--- Accuracy:  71.9%, Test Accuracy:  65.6%,  Validation Loss: 0.631
# Epochs 15--- Iterations: 364--- Accuracy:  68.8%, Test Accuracy:  50.0%,  Validation Loss: 0.707
# Epochs 16--- Iterations: 390--- Accuracy:  56.2%, Test Accuracy:  68.8%,  Validation Loss: 0.608
# Epochs 17--- Iterations: 416--- Accuracy:  75.0%, Test Accuracy:  53.1%,  Validation Loss: 0.707
# Epochs 18--- Iterations: 442--- Accuracy:  68.8%, Test Accuracy:  68.8%,  Validation Loss: 0.572
# Epochs 19--- Iterations: 468--- Accuracy:  62.5%, Test Accuracy:  56.2%,  Validation Loss: 0.726
# Epochs 20--- Iterations: 494--- Accuracy:  75.0%, Test Accuracy:  62.5%,  Validation Loss: 0.610
# Epochs 21--- Iterations: 520--- Accuracy:  81.2%, Test Accuracy:  62.5%,  Validation Loss: 0.579
# Epochs 22--- Iterations: 546--- Accuracy:  75.0%, Test Accuracy:  71.9%,  Validation Loss: 0.608
# Epochs 23--- Iterations: 572--- Accuracy:  71.9%, Test Accuracy:  56.2%,  Validation Loss: 0.761
# Epochs 24--- Iterations: 598--- Accuracy:  62.5%, Test Accuracy:  75.0%,  Validation Loss: 0.601
# Epochs 25--- Iterations: 624--- Accuracy:  68.8%, Test Accuracy:  62.5%,  Validation Loss: 0.660
# Epochs 26--- Iterations: 650--- Accuracy:  78.1%, Test Accuracy:  75.0%,  Validation Loss: 0.563
# Epochs 27--- Iterations: 676--- Accuracy:  81.2%, Test Accuracy:  59.4%,  Validation Loss: 0.606
# Epochs 28--- Iterations: 702--- Accuracy:  71.9%, Test Accuracy:  62.5%,  Validation Loss: 0.534
# Epochs 29--- Iterations: 728--- Accuracy:  68.8%, Test Accuracy:  59.4%,  Validation Loss: 0.745
# Epochs 30--- Iterations: 754--- Accuracy:  81.2%, Test Accuracy:  71.9%,  Validation Loss: 0.495
# Epochs 31--- Iterations: 780--- Accuracy:  71.9%, Test Accuracy:  59.4%,  Validation Loss: 0.696
# Epochs 32--- Iterations: 806--- Accuracy:  75.0%, Test Accuracy:  62.5%,  Validation Loss: 0.601
# Epochs 33--- Iterations: 832--- Accuracy:  81.2%, Test Accuracy:  65.6%,  Validation Loss: 0.673
# Epochs 34--- Iterations: 858--- Accuracy:  78.1%, Test Accuracy:  75.0%,  Validation Loss: 0.541
# Epochs 35--- Iterations: 884--- Accuracy:  78.1%, Test Accuracy:  59.4%,  Validation Loss: 0.748
# Epochs 36--- Iterations: 910--- Accuracy:  84.4%, Test Accuracy:  75.0%,  Validation Loss: 0.534
# Epochs 37--- Iterations: 936--- Accuracy:  84.4%, Test Accuracy:  62.5%,  Validation Loss: 0.636
# Epochs 38--- Iterations: 962--- Accuracy:  81.2%, Test Accuracy:  81.2%,  Validation Loss: 0.487
# Epochs 39--- Iterations: 988--- Accuracy:  90.6%, Test Accuracy:  68.8%,  Validation Loss: 0.736
# Epochs 40--- Iterations: 1014--- Accuracy:  84.4%, Test Accuracy:  78.1%,  Validation Loss: 0.474
# Epochs 41--- Iterations: 1040--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 0.656
# Epochs 42--- Iterations: 1066--- Accuracy:  90.6%, Test Accuracy:  71.9%,  Validation Loss: 0.508
# Epochs 43--- Iterations: 1092--- Accuracy:  84.4%, Test Accuracy:  62.5%,  Validation Loss: 0.667
# Epochs 44--- Iterations: 1118--- Accuracy:  90.6%, Test Accuracy:  65.6%,  Validation Loss: 0.527
# Epochs 45--- Iterations: 1144--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 0.711
# Epochs 46--- Iterations: 1170--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 0.448
# Epochs 47--- Iterations: 1196--- Accuracy:  87.5%, Test Accuracy:  59.4%,  Validation Loss: 0.652
# Epochs 48--- Iterations: 1222--- Accuracy:  81.2%, Test Accuracy:  75.0%,  Validation Loss: 0.469
# Epochs 49--- Iterations: 1248--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 0.795
# Epochs 50--- Iterations: 1274--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 0.398
# Epochs 51--- Iterations: 1300--- Accuracy:  90.6%, Test Accuracy:  71.9%,  Validation Loss: 0.607
# Epochs 52--- Iterations: 1326--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 0.445
# Epochs 53--- Iterations: 1352--- Accuracy:  93.8%, Test Accuracy:  59.4%,  Validation Loss: 0.712
# Epochs 54--- Iterations: 1378--- Accuracy:  90.6%, Test Accuracy:  81.2%,  Validation Loss: 0.610
# Epochs 55--- Iterations: 1404--- Accuracy:  96.9%, Test Accuracy:  53.1%,  Validation Loss: 0.887
# Epochs 56--- Iterations: 1430--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 0.562
# Epochs 57--- Iterations: 1456--- Accuracy:  96.9%, Test Accuracy:  65.6%,  Validation Loss: 0.872
# Epochs 58--- Iterations: 1482--- Accuracy:  87.5%, Test Accuracy:  81.2%,  Validation Loss: 0.576
# Epochs 59--- Iterations: 1508--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 1.007
# Epochs 60--- Iterations: 1534--- Accuracy:  90.6%, Test Accuracy:  87.5%,  Validation Loss: 0.555
# Epochs 61--- Iterations: 1560--- Accuracy:  96.9%, Test Accuracy:  56.2%,  Validation Loss: 0.784
# Epochs 62--- Iterations: 1586--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.613
# Epochs 63--- Iterations: 1612--- Accuracy:  90.6%, Test Accuracy:  59.4%,  Validation Loss: 1.044
# Epochs 64--- Iterations: 1638--- Accuracy: 100.0%, Test Accuracy:  78.1%,  Validation Loss: 0.465
# Epochs 65--- Iterations: 1664--- Accuracy:  90.6%, Test Accuracy:  62.5%,  Validation Loss: 0.901
# Epochs 66--- Iterations: 1690--- Accuracy:  90.6%, Test Accuracy:  78.1%,  Validation Loss: 0.526
# Epochs 67--- Iterations: 1716--- Accuracy: 100.0%, Test Accuracy:  71.9%,  Validation Loss: 1.008
# Epochs 68--- Iterations: 1742--- Accuracy:  93.8%, Test Accuracy:  87.5%,  Validation Loss: 0.531
# Epochs 69--- Iterations: 1768--- Accuracy:  93.8%, Test Accuracy:  68.8%,  Validation Loss: 1.125
# Epochs 70--- Iterations: 1794--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.499
# Epochs 71--- Iterations: 1820--- Accuracy:  96.9%, Test Accuracy:  65.6%,  Validation Loss: 0.955
# Epochs 72--- Iterations: 1846--- Accuracy: 100.0%, Test Accuracy:  68.8%,  Validation Loss: 0.608
# Epochs 73--- Iterations: 1872--- Accuracy:  90.6%, Test Accuracy:  53.1%,  Validation Loss: 1.085
# Epochs 74--- Iterations: 1898--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.648
# Epochs 75--- Iterations: 1924--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 1.262
# Epochs 76--- Iterations: 1950--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.770
# Epochs 77--- Iterations: 1976--- Accuracy: 100.0%, Test Accuracy:  62.5%,  Validation Loss: 0.962
# Epochs 78--- Iterations: 2002--- Accuracy:  96.9%, Test Accuracy:  75.0%,  Validation Loss: 0.619
# Epochs 79--- Iterations: 2028--- Accuracy: 100.0%, Test Accuracy:  50.0%,  Validation Loss: 1.407
# Epochs 80--- Iterations: 2054--- Accuracy:  96.9%, Test Accuracy:  71.9%,  Validation Loss: 0.541
# Epochs 81--- Iterations: 2080--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 1.479
# Epochs 82--- Iterations: 2106--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 0.459
# Epochs 83--- Iterations: 2132--- Accuracy: 100.0%, Test Accuracy:  62.5%,  Validation Loss: 1.007
# Epochs 84--- Iterations: 2158--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.410
# Epochs 85--- Iterations: 2184--- Accuracy:  90.6%, Test Accuracy:  53.1%,  Validation Loss: 1.080
# Epochs 86--- Iterations: 2210--- Accuracy:  96.9%, Test Accuracy:  90.6%,  Validation Loss: 0.795
# Epochs 87--- Iterations: 2236--- Accuracy:  90.6%, Test Accuracy:  62.5%,  Validation Loss: 0.989
# Epochs 88--- Iterations: 2262--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 0.623
# Epochs 89--- Iterations: 2288--- Accuracy:  96.9%, Test Accuracy:  53.1%,  Validation Loss: 1.310
# Epochs 90--- Iterations: 2314--- Accuracy:  96.9%, Test Accuracy:  84.4%,  Validation Loss: 0.778
# Epochs 91--- Iterations: 2340--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.524
# Epochs 92--- Iterations: 2366--- Accuracy:  96.9%, Test Accuracy:  90.6%,  Validation Loss: 0.555
# Epochs 93--- Iterations: 2392--- Accuracy:  96.9%, Test Accuracy:  65.6%,  Validation Loss: 1.453
# Epochs 94--- Iterations: 2418--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 0.876
# Epochs 95--- Iterations: 2444--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 1.062
# Epochs 96--- Iterations: 2470--- Accuracy:  96.9%, Test Accuracy:  84.4%,  Validation Loss: 0.926
# Epochs 97--- Iterations: 2496--- Accuracy:  93.8%, Test Accuracy:  56.2%,  Validation Loss: 1.925
# Epochs 98--- Iterations: 2522--- Accuracy:  87.5%, Test Accuracy:  78.1%,  Validation Loss: 0.632
# Epochs 99--- Iterations: 2548--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.855
# Epochs 100--- Iterations: 2574--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 0.778
# Epochs 101--- Iterations: 2600--- Accuracy:  93.8%, Test Accuracy:  56.2%,  Validation Loss: 1.365
# Epochs 102--- Iterations: 2626--- Accuracy: 100.0%, Test Accuracy:  87.5%,  Validation Loss: 0.898
# Epochs 103--- Iterations: 2652--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 1.286
# Epochs 104--- Iterations: 2678--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.765
# Epochs 105--- Iterations: 2704--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.330
# Epochs 106--- Iterations: 2730--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 0.720
# Epochs 107--- Iterations: 2756--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 1.515
# Epochs 108--- Iterations: 2782--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 1.265
# Epochs 109--- Iterations: 2808--- Accuracy:  90.6%, Test Accuracy:  59.4%,  Validation Loss: 2.068
# Epochs 110--- Iterations: 2834--- Accuracy:  93.8%, Test Accuracy:  71.9%,  Validation Loss: 1.277
# Epochs 111--- Iterations: 2860--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 0.931
# Epochs 112--- Iterations: 2886--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 1.102
# Epochs 113--- Iterations: 2912--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.667
# Epochs 114--- Iterations: 2938--- Accuracy:  90.6%, Test Accuracy:  78.1%,  Validation Loss: 0.901
# Epochs 115--- Iterations: 2964--- Accuracy:  96.9%, Test Accuracy:  46.9%,  Validation Loss: 2.293
# Epochs 116--- Iterations: 2990--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 1.431
# Epochs 117--- Iterations: 3016--- Accuracy:  90.6%, Test Accuracy:  62.5%,  Validation Loss: 2.192
# Epochs 118--- Iterations: 3042--- Accuracy: 100.0%, Test Accuracy:  78.1%,  Validation Loss: 1.626
# Epochs 119--- Iterations: 3068--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 2.691
# Epochs 120--- Iterations: 3094--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 1.267
# Epochs 121--- Iterations: 3120--- Accuracy:  87.5%, Test Accuracy:  59.4%,  Validation Loss: 2.618
# Epochs 122--- Iterations: 3146--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 1.515
# Epochs 123--- Iterations: 3172--- Accuracy:  90.6%, Test Accuracy:  56.2%,  Validation Loss: 1.773
# Epochs 124--- Iterations: 3198--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 1.500
# Epochs 125--- Iterations: 3224--- Accuracy:  90.6%, Test Accuracy:  56.2%,  Validation Loss: 2.877
# Epochs 126--- Iterations: 3250--- Accuracy:  93.8%, Test Accuracy:  71.9%,  Validation Loss: 0.572
# Epochs 127--- Iterations: 3276--- Accuracy:  96.9%, Test Accuracy:  53.1%,  Validation Loss: 2.927
# Epochs 128--- Iterations: 3302--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 1.156
# Epochs 129--- Iterations: 3328--- Accuracy:  96.9%, Test Accuracy:  50.0%,  Validation Loss: 3.450
# Epochs 130--- Iterations: 3354--- Accuracy:  96.9%, Test Accuracy:  71.9%,  Validation Loss: 1.812
# Epochs 131--- Iterations: 3380--- Accuracy:  90.6%, Test Accuracy:  56.2%,  Validation Loss: 1.996
# Epochs 132--- Iterations: 3406--- Accuracy: 100.0%, Test Accuracy:  71.9%,  Validation Loss: 1.584
# Epochs 133--- Iterations: 3432--- Accuracy:  96.9%, Test Accuracy:  43.8%,  Validation Loss: 2.694
# Epochs 134--- Iterations: 3458--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 1.546
# Epochs 135--- Iterations: 3484--- Accuracy: 100.0%, Test Accuracy:  59.4%,  Validation Loss: 2.866
# Epochs 136--- Iterations: 3510--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 0.650
# Epochs 137--- Iterations: 3536--- Accuracy:  96.9%, Test Accuracy:  53.1%,  Validation Loss: 1.764
# Epochs 138--- Iterations: 3562--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 1.588
# Epochs 139--- Iterations: 3588--- Accuracy:  96.9%, Test Accuracy:  56.2%,  Validation Loss: 2.351
# Epochs 140--- Iterations: 3614--- Accuracy:  96.9%, Test Accuracy:  93.8%,  Validation Loss: 0.662
# Epochs 141--- Iterations: 3640--- Accuracy:  93.8%, Test Accuracy:  53.1%,  Validation Loss: 1.465
# Epochs 142--- Iterations: 3666--- Accuracy:  87.5%, Test Accuracy:  81.2%,  Validation Loss: 0.809
# Epochs 143--- Iterations: 3692--- Accuracy:  90.6%, Test Accuracy:  56.2%,  Validation Loss: 1.818
# Epochs 144--- Iterations: 3718--- Accuracy:  96.9%, Test Accuracy:  84.4%,  Validation Loss: 1.013
# Epochs 145--- Iterations: 3744--- Accuracy:  93.8%, Test Accuracy:  53.1%,  Validation Loss: 2.155
# Epochs 146--- Iterations: 3770--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 0.736
# Epochs 147--- Iterations: 3796--- Accuracy: 100.0%, Test Accuracy:  59.4%,  Validation Loss: 1.452
# Epochs 148--- Iterations: 3822--- Accuracy: 100.0%, Test Accuracy:  75.0%,  Validation Loss: 0.817
# Epochs 149--- Iterations: 3848--- Accuracy:  90.6%, Test Accuracy:  68.8%,  Validation Loss: 1.081
# Epochs 150--- Iterations: 3874--- Accuracy:  96.9%, Test Accuracy:  90.6%,  Validation Loss: 0.950
# Epochs 151--- Iterations: 3900--- Accuracy:  90.6%, Test Accuracy:  71.9%,  Validation Loss: 1.676
# Epochs 152--- Iterations: 3926--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.936
# Epochs 153--- Iterations: 3952--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 1.648
# Epochs 154--- Iterations: 3978--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 0.596
# Epochs 155--- Iterations: 4004--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.840
# Epochs 156--- Iterations: 4030--- Accuracy:  90.6%, Test Accuracy:  84.4%,  Validation Loss: 0.674
# Epochs 157--- Iterations: 4056--- Accuracy:  96.9%, Test Accuracy:  65.6%,  Validation Loss: 1.830
# Epochs 158--- Iterations: 4082--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 0.703
# Epochs 159--- Iterations: 4108--- Accuracy:  93.8%, Test Accuracy:  53.1%,  Validation Loss: 0.961
# Epochs 160--- Iterations: 4134--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 1.228
# Epochs 161--- Iterations: 4160--- Accuracy: 100.0%, Test Accuracy:  53.1%,  Validation Loss: 2.350
# Epochs 162--- Iterations: 4186--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 1.072
# Epochs 163--- Iterations: 4212--- Accuracy:  87.5%, Test Accuracy:  65.6%,  Validation Loss: 1.948
# Epochs 164--- Iterations: 4238--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.682
# Epochs 165--- Iterations: 4264--- Accuracy: 100.0%, Test Accuracy:  65.6%,  Validation Loss: 1.941
# Epochs 166--- Iterations: 4290--- Accuracy:  90.6%, Test Accuracy:  81.2%,  Validation Loss: 1.152
# Epochs 167--- Iterations: 4316--- Accuracy:  96.9%, Test Accuracy:  68.8%,  Validation Loss: 1.699
# Epochs 168--- Iterations: 4342--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 0.763
# Epochs 169--- Iterations: 4368--- Accuracy:  84.4%, Test Accuracy:  56.2%,  Validation Loss: 1.230
# Epochs 170--- Iterations: 4394--- Accuracy:  90.6%, Test Accuracy:  87.5%,  Validation Loss: 1.177
# Epochs 171--- Iterations: 4420--- Accuracy: 100.0%, Test Accuracy:  68.8%,  Validation Loss: 2.653
# Epochs 172--- Iterations: 4446--- Accuracy:  96.9%, Test Accuracy:  84.4%,  Validation Loss: 0.851
# Epochs 173--- Iterations: 4472--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 1.732
# Epochs 174--- Iterations: 4498--- Accuracy:  90.6%, Test Accuracy:  90.6%,  Validation Loss: 0.741
# Epochs 175--- Iterations: 4524--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 2.161
# Epochs 176--- Iterations: 4550--- Accuracy:  93.8%, Test Accuracy:  90.6%,  Validation Loss: 0.782
# Epochs 177--- Iterations: 4576--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.356
# Epochs 178--- Iterations: 4602--- Accuracy:  87.5%, Test Accuracy:  81.2%,  Validation Loss: 1.129
# Epochs 179--- Iterations: 4628--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 2.030
# Epochs 180--- Iterations: 4654--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 0.688
# Epochs 181--- Iterations: 4680--- Accuracy:  90.6%, Test Accuracy:  68.8%,  Validation Loss: 2.208
# Epochs 182--- Iterations: 4706--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 1.179
# Epochs 183--- Iterations: 4732--- Accuracy:  90.6%, Test Accuracy:  65.6%,  Validation Loss: 1.632
# Epochs 184--- Iterations: 4758--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 1.297
# Epochs 185--- Iterations: 4784--- Accuracy:  93.8%, Test Accuracy:  59.4%,  Validation Loss: 2.091
# Epochs 186--- Iterations: 4810--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 1.216
# Epochs 187--- Iterations: 4836--- Accuracy:  96.9%, Test Accuracy:  68.8%,  Validation Loss: 2.447
# Epochs 188--- Iterations: 4862--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.933
# Epochs 189--- Iterations: 4888--- Accuracy:  96.9%, Test Accuracy:  56.2%,  Validation Loss: 1.786
# Epochs 190--- Iterations: 4914--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 1.344
# Epochs 191--- Iterations: 4940--- Accuracy:  96.9%, Test Accuracy:  68.8%,  Validation Loss: 2.352
# Epochs 192--- Iterations: 4966--- Accuracy:  90.6%, Test Accuracy:  84.4%,  Validation Loss: 0.700
# Epochs 193--- Iterations: 4992--- Accuracy:  90.6%, Test Accuracy:  53.1%,  Validation Loss: 2.031
# Epochs 194--- Iterations: 5018--- Accuracy:  96.9%, Test Accuracy:  93.8%,  Validation Loss: 0.763
# Epochs 195--- Iterations: 5044--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 1.795
# Epochs 196--- Iterations: 5070--- Accuracy: 100.0%, Test Accuracy:  75.0%,  Validation Loss: 0.726
# Epochs 197--- Iterations: 5096--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 2.526
# Epochs 198--- Iterations: 5122--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.652
# Epochs 199--- Iterations: 5148--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 2.429
# Epochs 200--- Iterations: 5174--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 0.761
# Epochs 201--- Iterations: 5200--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.287
# Epochs 202--- Iterations: 5226--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 1.369
# Epochs 203--- Iterations: 5252--- Accuracy:  93.8%, Test Accuracy:  71.9%,  Validation Loss: 1.820
# Epochs 204--- Iterations: 5278--- Accuracy:  93.8%, Test Accuracy:  90.6%,  Validation Loss: 1.397
# Epochs 205--- Iterations: 5304--- Accuracy:  90.6%, Test Accuracy:  68.8%,  Validation Loss: 1.696
# Epochs 206--- Iterations: 5330--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.827
# Epochs 207--- Iterations: 5356--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.475
# Epochs 208--- Iterations: 5382--- Accuracy: 100.0%, Test Accuracy:  90.6%,  Validation Loss: 0.811
# Epochs 209--- Iterations: 5408--- Accuracy:  90.6%, Test Accuracy:  81.2%,  Validation Loss: 2.841
# Epochs 210--- Iterations: 5434--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 0.354
# Epochs 211--- Iterations: 5460--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 2.697
# Epochs 212--- Iterations: 5486--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 1.196
# Epochs 213--- Iterations: 5512--- Accuracy:  90.6%, Test Accuracy:  62.5%,  Validation Loss: 2.045
# Epochs 214--- Iterations: 5538--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 1.306
# Epochs 215--- Iterations: 5564--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.745
# Epochs 216--- Iterations: 5590--- Accuracy:  90.6%, Test Accuracy:  90.6%,  Validation Loss: 1.519
# Epochs 217--- Iterations: 5616--- Accuracy: 100.0%, Test Accuracy:  68.8%,  Validation Loss: 2.932
# Epochs 218--- Iterations: 5642--- Accuracy:  87.5%, Test Accuracy:  81.2%,  Validation Loss: 1.425
# Epochs 219--- Iterations: 5668--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.240
# Epochs 220--- Iterations: 5694--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 1.422
# Epochs 221--- Iterations: 5720--- Accuracy:  96.9%, Test Accuracy:  56.2%,  Validation Loss: 1.912
# Epochs 222--- Iterations: 5746--- Accuracy:  87.5%, Test Accuracy:  78.1%,  Validation Loss: 1.303
# Epochs 223--- Iterations: 5772--- Accuracy:  90.6%, Test Accuracy:  68.8%,  Validation Loss: 2.394
# Epochs 224--- Iterations: 5798--- Accuracy:  90.6%, Test Accuracy:  81.2%,  Validation Loss: 0.958
# Epochs 225--- Iterations: 5824--- Accuracy:  87.5%, Test Accuracy:  68.8%,  Validation Loss: 3.000
# Epochs 226--- Iterations: 5850--- Accuracy: 100.0%, Test Accuracy:  78.1%,  Validation Loss: 0.713
# Epochs 227--- Iterations: 5876--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 2.200
# Epochs 228--- Iterations: 5902--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 0.933
# Epochs 229--- Iterations: 5928--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 3.172
# Epochs 230--- Iterations: 5954--- Accuracy:  90.6%, Test Accuracy:  87.5%,  Validation Loss: 0.758
# Epochs 231--- Iterations: 5980--- Accuracy:  93.8%, Test Accuracy:  59.4%,  Validation Loss: 2.538
# Epochs 232--- Iterations: 6006--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 0.711
# Epochs 233--- Iterations: 6032--- Accuracy: 100.0%, Test Accuracy:  65.6%,  Validation Loss: 2.389
# Epochs 234--- Iterations: 6058--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 0.381
# Epochs 235--- Iterations: 6084--- Accuracy:  84.4%, Test Accuracy:  59.4%,  Validation Loss: 2.655
# Epochs 236--- Iterations: 6110--- Accuracy:  84.4%, Test Accuracy:  87.5%,  Validation Loss: 1.387
# Epochs 237--- Iterations: 6136--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.353
# Epochs 238--- Iterations: 6162--- Accuracy: 100.0%, Test Accuracy:  71.9%,  Validation Loss: 0.816
# Epochs 239--- Iterations: 6188--- Accuracy:  87.5%, Test Accuracy:  65.6%,  Validation Loss: 2.277
# Epochs 240--- Iterations: 6214--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 1.421
# Epochs 241--- Iterations: 6240--- Accuracy: 100.0%, Test Accuracy:  71.9%,  Validation Loss: 2.863
# Epochs 242--- Iterations: 6266--- Accuracy:  87.5%, Test Accuracy:  87.5%,  Validation Loss: 0.292
# Epochs 243--- Iterations: 6292--- Accuracy: 100.0%, Test Accuracy:  62.5%,  Validation Loss: 2.609
# Epochs 244--- Iterations: 6318--- Accuracy:  90.6%, Test Accuracy:  81.2%,  Validation Loss: 1.052
# Epochs 245--- Iterations: 6344--- Accuracy: 100.0%, Test Accuracy:  50.0%,  Validation Loss: 1.765
# Epochs 246--- Iterations: 6370--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.841
# Epochs 247--- Iterations: 6396--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 1.903
# Epochs 248--- Iterations: 6422--- Accuracy:  93.8%, Test Accuracy:  81.2%,  Validation Loss: 0.902
# Epochs 249--- Iterations: 6448--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 2.333
# Epochs 250--- Iterations: 6474--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 1.488
# Epochs 251--- Iterations: 6500--- Accuracy:  93.8%, Test Accuracy:  59.4%,  Validation Loss: 1.578
# Epochs 252--- Iterations: 6526--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 1.131
# Epochs 253--- Iterations: 6552--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 1.805
# Epochs 254--- Iterations: 6578--- Accuracy:  93.8%, Test Accuracy:  87.5%,  Validation Loss: 1.426
# Epochs 255--- Iterations: 6604--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.601
# Epochs 256--- Iterations: 6630--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 1.539
# Epochs 257--- Iterations: 6656--- Accuracy:  96.9%, Test Accuracy:  68.8%,  Validation Loss: 2.874
# Epochs 258--- Iterations: 6682--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 1.488
# Epochs 259--- Iterations: 6708--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.964
# Epochs 260--- Iterations: 6734--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 1.579
# Epochs 261--- Iterations: 6760--- Accuracy:  93.8%, Test Accuracy:  56.2%,  Validation Loss: 3.210
# Epochs 262--- Iterations: 6786--- Accuracy:  93.8%, Test Accuracy:  78.1%,  Validation Loss: 0.877
# Epochs 263--- Iterations: 6812--- Accuracy:  90.6%, Test Accuracy:  62.5%,  Validation Loss: 1.559
# Epochs 264--- Iterations: 6838--- Accuracy:  90.6%, Test Accuracy:  78.1%,  Validation Loss: 0.552
# Epochs 265--- Iterations: 6864--- Accuracy:  93.8%, Test Accuracy:  68.8%,  Validation Loss: 2.669
# Epochs 266--- Iterations: 6890--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 0.814
# Epochs 267--- Iterations: 6916--- Accuracy:  96.9%, Test Accuracy:  56.2%,  Validation Loss: 2.515
# Epochs 268--- Iterations: 6942--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 1.480
# Epochs 269--- Iterations: 6968--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 3.158
# Epochs 270--- Iterations: 6994--- Accuracy: 100.0%, Test Accuracy:  75.0%,  Validation Loss: 1.826
# Epochs 271--- Iterations: 7020--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.147
# Epochs 272--- Iterations: 7046--- Accuracy:  93.8%, Test Accuracy:  87.5%,  Validation Loss: 1.228
# Epochs 273--- Iterations: 7072--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.605
# Epochs 274--- Iterations: 7098--- Accuracy:  90.6%, Test Accuracy:  87.5%,  Validation Loss: 0.404
# Epochs 275--- Iterations: 7124--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.173
# Epochs 276--- Iterations: 7150--- Accuracy: 100.0%, Test Accuracy:  87.5%,  Validation Loss: 1.536
# Epochs 277--- Iterations: 7176--- Accuracy:  93.8%, Test Accuracy:  62.5%,  Validation Loss: 2.244
# Epochs 278--- Iterations: 7202--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 0.174
# Epochs 279--- Iterations: 7228--- Accuracy:  96.9%, Test Accuracy:  71.9%,  Validation Loss: 3.386
# Epochs 280--- Iterations: 7254--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 1.708
# Epochs 281--- Iterations: 7280--- Accuracy:  90.6%, Test Accuracy:  56.2%,  Validation Loss: 3.003
# Epochs 282--- Iterations: 7306--- Accuracy:  93.8%, Test Accuracy:  75.0%,  Validation Loss: 0.259
# Epochs 283--- Iterations: 7332--- Accuracy:  93.8%, Test Accuracy:  59.4%,  Validation Loss: 3.914
# Epochs 284--- Iterations: 7358--- Accuracy:  87.5%, Test Accuracy:  90.6%,  Validation Loss: 1.546
# Epochs 285--- Iterations: 7384--- Accuracy:  93.8%, Test Accuracy:  53.1%,  Validation Loss: 3.136
# Epochs 286--- Iterations: 7410--- Accuracy:  90.6%, Test Accuracy:  75.0%,  Validation Loss: 1.644
# Epochs 287--- Iterations: 7436--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 3.662
# Epochs 288--- Iterations: 7462--- Accuracy:  87.5%, Test Accuracy:  68.8%,  Validation Loss: 1.209
# Epochs 289--- Iterations: 7488--- Accuracy:  96.9%, Test Accuracy:  62.5%,  Validation Loss: 2.339
# Epochs 290--- Iterations: 7514--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 0.801
# Epochs 291--- Iterations: 7540--- Accuracy:  93.8%, Test Accuracy:  56.2%,  Validation Loss: 1.707
# Epochs 292--- Iterations: 7566--- Accuracy:  96.9%, Test Accuracy:  87.5%,  Validation Loss: 1.196
# Epochs 293--- Iterations: 7592--- Accuracy:  90.6%, Test Accuracy:  65.6%,  Validation Loss: 1.489
# Epochs 294--- Iterations: 7618--- Accuracy:  93.8%, Test Accuracy:  84.4%,  Validation Loss: 0.634
# Epochs 295--- Iterations: 7644--- Accuracy:  96.9%, Test Accuracy:  65.6%,  Validation Loss: 1.427
# Epochs 296--- Iterations: 7670--- Accuracy:  93.8%, Test Accuracy:  87.5%,  Validation Loss: 1.183
# Epochs 297--- Iterations: 7696--- Accuracy:  96.9%, Test Accuracy:  59.4%,  Validation Loss: 1.958
# Epochs 298--- Iterations: 7722--- Accuracy:  90.6%, Test Accuracy:  78.1%,  Validation Loss: 0.731
# Epochs 299--- Iterations: 7748--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 1.580
# Epochs 300--- Iterations: 7774--- Accuracy:  96.9%, Test Accuracy:  81.2%,  Validation Loss: 0.758
# Epochs 301--- Iterations: 7800--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.496
# Epochs 302--- Iterations: 7826--- Accuracy:  96.9%, Test Accuracy:  78.1%,  Validation Loss: 1.068
# Epochs 303--- Iterations: 7852--- Accuracy: 100.0%, Test Accuracy:  56.2%,  Validation Loss: 2.605
# Epochs 304--- Iterations: 7878--- Accuracy: 100.0%, Test Accuracy:  81.2%,  Validation Loss: 1.473
# Epochs 305--- Iterations: 7904--- Accuracy:  87.5%, Test Accuracy:  56.2%,  Validation Loss: 2.484
# Epochs 306--- Iterations: 7930--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 1.270
# Epochs 307--- Iterations: 7956--- Accuracy:  93.8%, Test Accuracy:  65.6%,  Validation Loss: 2.579
# Epochs 308--- Iterations: 7982--- Accuracy: 100.0%, Test Accuracy:  84.4%,  Validation Loss: 0.813

# %% [markdown]
# ## Predicting using models

# %%
import sys,argparse

# %%
pic_size=64
channel=3
images = []

path = './Pixiebob.jpg'
image = cv2.imread(path)
# Resizing the image 
image = cv2.resize(image, (pic_size, pic_size),0,0, cv2.INTER_LINEAR)
images.append(image)
images = np.array(images, dtype=np.uint8)
images = images.astype('float32')
images = np.multiply(images, 1.0/255.0) 

# The input to the network 
x_batch = images.reshape(1, pic_size,pic_size,channel)

# Restore the saved model 
sess = tf.Session()

# Recreate the network graph. At this step only graph is created.
saver = tf.train.import_meta_graph('./dogs-cats-model/dog-cat.ckpt-7982.meta')

# Load the weights saved using the restore method.
saver.restore(sess, './dogs-cats-model/dog-cat.ckpt-7982')

# Accessing the default graph which we have restored
graph = tf.get_default_graph()

# In the original network y_pred is the tensor that is the prediction of the network
y_pred = graph.get_tensor_by_name("y_pred:0")

# Feed the images to the input placeholders
x= graph.get_tensor_by_name("x:0") 
y_true = graph.get_tensor_by_name("y_true:0") 
y_test_images = np.zeros((1, 2)) 


### Creating the feed_dict that is required to be fed to calculate y_pred 
feed_dict_testing = {x: x_batch, y_true: y_test_images}
result=sess.run(y_pred, feed_dict=feed_dict_testing)
# result is of this format :
# dog [1 0]
res_label = ['dog','cat']
print(res_label[result.argmax()])
# Out:
# INFO:tensorflow:Restoring parameters from ./dogs-cats-model/dog-cat.ckpt-7982
# cat

# %% [markdown]
# ## Attribution

# %% [markdown]
# The code in the document by Yudi Tang is opened to use for study on 163:
# http://study.163.com/course/courseMain.htm?courseId=1003606092
